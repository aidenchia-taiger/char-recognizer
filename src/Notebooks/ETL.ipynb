# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import shutil
import cv2
from random import shuffle
from Utils import display, save, makeDir, is_binary

# %%
# !pwd
# Out:
# /home/aidenchia/Documents/char-recognizer/src

# %%
def binarizeAllFiles(src, dst='../out/', method='normal', classLabelPos=2):
    for root, dirs, files in os.walk(src):
        for file in files:
            if '.png' not in file:
                continue
                
            filepath = os.path.join(root, file)
            print('[INFO] Loading file: {}'.format(filepath))
            img = cv2.imread(filepath, cv2.IMREAD_GRAYSCALE)
            if method == 'normal':
                img = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)[-1]
            elif method == 'inverse':
                img = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY_INV)[-1]
                
            classLabel = root.split('/')[classLabelPos]
            save(img, name=file, prefix=dst + classLabel, suffix=None)

# %%
def countNumImgFiles(directory):
    numFiles = 0
    for root, dirs, files in os.walk(directory):
        for file in files:
            if '.png' not in file:
                continue
            numFiles+= 1
    print('No. of Files in {}: {}'.format(directory, numFiles))
    return numFiles

# %%
def renameAllFiles(src, newName, classLabelPos=2):
    for root, dirs, files in os.walk(src):
        for file in files:
            if '.png' not in file:
                continue
            old = os.path.join(root, file)
            new = os.path.join(root, newName+file)
            print('[INFO] Renaming {} to {}'.format(old, new))
            os.rename(old, new)
            new = ""

# %%
def copyOverIfExists(src, dst, imgpath):
    fullSrcPath = os.path.join(src, imgpath)
    makeDir(dst)
    fullDstPath = os.path.join(dst, imgpath)
    if not os.path.exists(fullDstPath):
        print('[INFO] Moving {} to {}'.format(fullSrcPath, fullDstPath))
        shutil.move(fullSrcPath, fullDstPath)

# %%
def mergeIntoFolder(src, dst, classLabelPos=2):
    for root, dirs, files in os.walk(src):
        for file in files:
            classLabel = root.split('/')[classLabelPos]
            dstPath = dst + classLabel
            copyOverIfExists(root, dstPath, file)

# %% [markdown]
# ## Prepare EMNIST Data

# %%
df = pd.read_csv('../EMNIST/emnist-balanced-test.csv', header=None)
df.head()

# %%
print('Total No. of Images:', df.shape[0])

# %%
classes = df[0].values
flattened = df.drop(0, axis=1).values
print('No. of Classes:', len(np.unique(classes)))

# %%
f = open('../EMNIST/emnist-balanced-mapping.txt')
mapping = {}
for line in f.readlines():
    line = line.split()
    classNum = int(line[0])
    gt = chr(int(line[1]))
    mapping[classNum] = gt
    
print(mapping)

# %%
from random import randint
pick = randint(0,47)
img = flattened[pick].reshape((28,28)).transpose()
print('Class:', mapping[classes[pick]])
print('Unique values: ', np.unique(img))
display(img)

# %%
for idx, i in enumerate(range(len(flattened))):
    img = flattened[i].reshape((28,28)).transpose()
    gt = mapping[classes[i]]
    save(img, name=str(idx), prefix= os.path.join('../imgs/test', gt), suffix='.png')

# %%
img = cv2.imread('../imgs/0/156.png', cv2.IMREAD_GRAYSCALE)
print(np.unique(img))
img = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)[-1]
print(np.unique(img))
display(img)

# %%
binarizeAllFiles(src='../imgs', dst='../out/', method='normal')

# %%
is_binary(cv2.imread('../imgs/0/156.png'))

# %%
assert countNumImgFiles('../imgs') == countNumImgFiles('../out')

# %%
renameAllFiles('../imgs/', 'EMNIST_')

# %% [markdown]
# ## Combine Hnd Data

# %%
files = [x for x in os.listdir('../Hnd/Img') if '.txt' not in x]
files.sort()
print(files)

# %%
gt = [ x for x in '0123456789ABCDEFGHIJKLMNOPQRSTUVWXYZabcdefghiklmnopqrstuvwxyz']
print(gt)

# %%
binarizeAllFiles(src='../Hnd/Img', dst='../Hnd/Out/', method='inverse', classLabelPos=3)

# %%
assert countNumImgFiles('../Hnd/Img/') == countNumImgFiles('../Hnd/Out')

# %%
renameAllFiles('../Hnd/Out', 'Hnd_', 3)

# %%
shutil.copy('../Hnd/Out/L/Hnd_img022-027.png', '../imgs/L/Hnd_img022-027.png')

# %%
mergeIntoFolder('../Hnd/Out', '../imgs/', classLabelPos=3)

# %%
countNumImgFiles('../imgs/')

# %% [markdown]
# ## Balance Classes

# %%
# !pwd

# %%
files = []
src = '../imgs/train/slash'
dst = '../imgs/test/slash'
makeDir(dst)
for file in os.listdir(src):
    if '.png' not in file:
        continue
    files.append(file)

shuffle(files)
files = files[0: int(0.1 * len(files))]
for file in files:
    copyOverIfExists(src, dst, file)

# %% [markdown]
# ## Create Validation Set

# %%
def makeValSet(src):
    classLabel = src.split('/')[-1]
    files = [x for x in os.listdir(src) if '.png' in x]
    shuffle(files)
    files = files[0: int(0.1 * len(files))]
    print(len(files))
    for file in files:
        dst = os.path.join('../imgs/validation/{}'.format(classLabel))
        copyOverIfExists(src, dst, file)

# %%
srcs = ['../imgs/train/' + x for x in os.listdir('../imgs/train/')]
print(srcs)
# Out:
# ['../imgs/train/$', '../imgs/train/)', '../imgs/train/L', '../imgs/train/H', '../imgs/train/N', '../imgs/train/2', '../imgs/train/I', '../imgs/train/D', '../imgs/train/b', '../imgs/train/1', '../imgs/train/f', '../imgs/train/J', '../imgs/train/E', '../imgs/train/Y', '../imgs/train/h', '../imgs/train/e', '../imgs/train/7', '../imgs/train/@', '../imgs/train/C', '../imgs/train/r', '../imgs/train/#', '../imgs/train/F', '../imgs/train/q', '../imgs/train/X', '../imgs/train/P', '../imgs/train/(', '../imgs/train/0', '../imgs/train/A', '../imgs/train/6', '../imgs/train/O', '../imgs/train/W', '../imgs/train/U', '../imgs/train/T', '../imgs/train/9', '../imgs/train/M', '../imgs/train/R', '../imgs/train/V', '../imgs/train/G', '../imgs/train/B', '../imgs/train/5', '../imgs/train/t', '../imgs/train/3', '../imgs/train/8', '../imgs/train/a', '../imgs/train/4', '../imgs/train/slash', '../imgs/train/Z', '../imgs/train/Q', '../imgs/train/n', '../imgs/train/K', '../imgs/train/g', '../imgs/train/d', '../imgs/train/S']

# %%
for src in srcs:
    makeValSet(src)
# Out:
# 240
# [INFO] Moving ../imgs/train/$/__6_634336.png to ../imgs/validation/$/__6_634336.png
# [INFO] Moving ../imgs/train/$/__16_1717897.png to ../imgs/validation/$/__16_1717897.png
# [INFO] Moving ../imgs/train/$/__21_1361250.png to ../imgs/validation/$/__21_1361250.png
# [INFO] Moving ../imgs/train/$/__20_6946443.png to ../imgs/validation/$/__20_6946443.png
# [INFO] Moving ../imgs/train/$/__16_7960528.png to ../imgs/validation/$/__16_7960528.png
# [INFO] Moving ../imgs/train/$/__15_6527856.png to ../imgs/validation/$/__15_6527856.png
# [INFO] Moving ../imgs/train/$/__6_8485190.png to ../imgs/validation/$/__6_8485190.png
# [INFO] Moving ../imgs/train/$/__24_5591369.png to ../imgs/validation/$/__24_5591369.png
# [INFO] Moving ../imgs/train/$/__23_8302420.png to ../imgs/validation/$/__23_8302420.png
# [INFO] Moving ../imgs/train/$/__20_8357698.png to ../imgs/validation/$/__20_8357698.png
# [INFO] Moving ../imgs/train/$/__0_3385325.png to ../imgs/validation/$/__0_3385325.png
# [INFO] Moving ../imgs/train/$/__24_5588113.png to ../imgs/validation/$/__24_5588113.png
# [INFO] Moving ../imgs/train/$/__12_2701555.png to ../imgs/validation/$/__12_2701555.png
# [INFO] Moving ../imgs/train/$/__16_9491897.png to ../imgs/validation/$/__16_9491897.png
# [INFO] Moving ../imgs/train/$/__26_8976371.png to ../imgs/validation/$/__26_8976371.png
# [INFO] Moving ../imgs/train/$/__9_6058150.png to ../imgs/validation/$/__9_6058150.png
# [INFO] Moving ../imgs/train/$/__9_258142.png to ../imgs/validation/$/__9_258142.png
# [INFO] Moving ../imgs/train/$/__18_8888493.png to ../imgs/validation/$/__18_8888493.png
# [INFO] Moving ../imgs/train/$/__19_9220130.png to ../imgs/validation/$/__19_9220130.png
# [INFO] Moving ../imgs/train/$/__24_4648660.png to ../imgs/validation/$/__24_4648660.png
# [INFO] Moving ../imgs/train/$/__7_1070462.png to ../imgs/validation/$/__7_1070462.png
# [INFO] Moving ../imgs/train/$/__10_4241074.png to ../imgs/validation/$/__10_4241074.png
# [INFO] Moving ../imgs/train/$/__11_3364106.png to ../imgs/validation/$/__11_3364106.png
# [INFO] Moving ../imgs/train/$/__12_2909628.png to ../imgs/validation/$/__12_2909628.png
# [INFO] Moving ../imgs/train/$/__10_9028678.png to ../imgs/validation/$/__10_9028678.png
# [INFO] Moving ../imgs/train/$/__1_614178.png to ../imgs/validation/$/__1_614178.png
# [INFO] Moving ../imgs/train/$/__15_8407401.png to ../imgs/validation/$/__15_8407401.png
# [INFO] Moving ../imgs/train/$/__6_3264436.png to ../imgs/validation/$/__6_3264436.png
# [INFO] Moving ../imgs/train/$/__19_8482832.png to ../imgs/validation/$/__19_8482832.png
# [INFO] Moving ../imgs/train/$/__25_3304562.png to ../imgs/validation/$/__25_3304562.png
# [INFO] Moving ../imgs/train/$/__3_6306872.png to ../imgs/validation/$/__3_6306872.png
# [INFO] Moving ../imgs/train/$/__20_8382610.png to ../imgs/validation/$/__20_8382610.png
# [INFO] Moving ../imgs/train/$/__1_3818071.png to ../imgs/validation/$/__1_3818071.png
# [INFO] Moving ../imgs/train/$/__13_4178397.png to ../imgs/validation/$/__13_4178397.png
# [INFO] Moving ../imgs/train/$/__14_8793874.png to ../imgs/validation/$/__14_8793874.png
# [INFO] Moving ../imgs/train/$/__7_2454941.png to ../imgs/validation/$/__7_2454941.png
# [INFO] Moving ../imgs/train/$/__15_2257630.png to ../imgs/validation/$/__15_2257630.png
# [INFO] Moving ../imgs/train/$/__9_9481355.png to ../imgs/validation/$/__9_9481355.png
# [INFO] Moving ../imgs/train/$/__11_9788975.png to ../imgs/validation/$/__11_9788975.png
# [INFO] Moving ../imgs/train/$/__5_2644726.png to ../imgs/validation/$/__5_2644726.png
# [INFO] Moving ../imgs/train/$/__14_7645962.png to ../imgs/validation/$/__14_7645962.png
# [INFO] Moving ../imgs/train/$/__16_5156157.png to ../imgs/validation/$/__16_5156157.png
# [INFO] Moving ../imgs/train/$/__3_4095204.png to ../imgs/validation/$/__3_4095204.png
# [INFO] Moving ../imgs/train/$/__5_3758011.png to ../imgs/validation/$/__5_3758011.png
# [INFO] Moving ../imgs/train/$/__2_9784532.png to ../imgs/validation/$/__2_9784532.png
# [INFO] Moving ../imgs/train/$/__21_4931982.png to ../imgs/validation/$/__21_4931982.png
# [INFO] Moving ../imgs/train/$/__18_6526572.png to ../imgs/validation/$/__18_6526572.png
# [INFO] Moving ../imgs/train/$/__11_2553639.png to ../imgs/validation/$/__11_2553639.png
# [INFO] Moving ../imgs/train/$/__14_4283519.png to ../imgs/validation/$/__14_4283519.png
# [INFO] Moving ../imgs/train/$/__22_7796854.png to ../imgs/validation/$/__22_7796854.png
# [INFO] Moving ../imgs/train/$/__14_1319775.png to ../imgs/validation/$/__14_1319775.png
# [INFO] Moving ../imgs/train/$/__10_6952004.png to ../imgs/validation/$/__10_6952004.png
# [INFO] Moving ../imgs/train/$/__2_3344026.png to ../imgs/validation/$/__2_3344026.png
# [INFO] Moving ../imgs/train/$/__7_9524794.png to ../imgs/validation/$/__7_9524794.png
# [INFO] Moving ../imgs/train/$/__19_5958221.png to ../imgs/validation/$/__19_5958221.png
# [INFO] Moving ../imgs/train/$/__4_8789467.png to ../imgs/validation/$/__4_8789467.png
# [INFO] Moving ../imgs/train/$/__25_277335.png to ../imgs/validation/$/__25_277335.png
# [INFO] Moving ../imgs/train/$/__15_9591442.png to ../imgs/validation/$/__15_9591442.png
# [INFO] Moving ../imgs/train/$/__4_1623645.png to ../imgs/validation/$/__4_1623645.png
# [INFO] Moving ../imgs/train/$/__23_9275115.png to ../imgs/validation/$/__23_9275115.png
# [INFO] Moving ../imgs/train/$/__26_3828998.png to ../imgs/validation/$/__26_3828998.png
# [INFO] Moving ../imgs/train/$/__18_9162874.png to ../imgs/validation/$/__18_9162874.png
# [INFO] Moving ../imgs/train/$/__9_1577672.png to ../imgs/validation/$/__9_1577672.png
# [INFO] Moving ../imgs/train/$/__18_7594873.png to ../imgs/validation/$/__18_7594873.png
# [INFO] Moving ../imgs/train/$/__2_9976665.png to ../imgs/validation/$/__2_9976665.png
# [INFO] Moving ../imgs/train/$/__9_4326731.png to ../imgs/validation/$/__9_4326731.png
# [INFO] Moving ../imgs/train/$/__8_7121724.png to ../imgs/validation/$/__8_7121724.png
# [INFO] Moving ../imgs/train/$/__14_8361698.png to ../imgs/validation/$/__14_8361698.png
# [INFO] Moving ../imgs/train/$/__10_362725.png to ../imgs/validation/$/__10_362725.png
# [INFO] Moving ../imgs/train/$/__5_7299161.png to ../imgs/validation/$/__5_7299161.png
# [INFO] Moving ../imgs/train/$/__10_6426554.png to ../imgs/validation/$/__10_6426554.png
# [INFO] Moving ../imgs/train/$/__1_5389481.png to ../imgs/validation/$/__1_5389481.png
# [INFO] Moving ../imgs/train/$/__26_6059563.png to ../imgs/validation/$/__26_6059563.png
# [INFO] Moving ../imgs/train/$/__12_4425808.png to ../imgs/validation/$/__12_4425808.png
# [INFO] Moving ../imgs/train/$/__3_1527801.png to ../imgs/validation/$/__3_1527801.png
# [INFO] Moving ../imgs/train/$/__10_9436775.png to ../imgs/validation/$/__10_9436775.png
# [INFO] Moving ../imgs/train/$/__9_9624831.png to ../imgs/validation/$/__9_9624831.png
# [INFO] Moving ../imgs/train/$/__24_4677409.png to ../imgs/validation/$/__24_4677409.png
# [INFO] Moving ../imgs/train/$/__16_9335057.png to ../imgs/validation/$/__16_9335057.png
# [INFO] Moving ../imgs/train/$/__16_3749872.png to ../imgs/validation/$/__16_3749872.png
# [INFO] Moving ../imgs/train/$/__20_4408846.png to ../imgs/validation/$/__20_4408846.png
# [INFO] Moving ../imgs/train/$/__5_4382665.png to ../imgs/validation/$/__5_4382665.png
# [INFO] Moving ../imgs/train/$/__7_1742645.png to ../imgs/validation/$/__7_1742645.png
# [INFO] Moving ../imgs/train/$/__7_7908933.png to ../imgs/validation/$/__7_7908933.png
# [INFO] Moving ../imgs/train/$/__19_7650148.png to ../imgs/validation/$/__19_7650148.png
# [INFO] Moving ../imgs/train/$/__14_6309244.png to ../imgs/validation/$/__14_6309244.png
# [INFO] Moving ../imgs/train/$/__1_5060867.png to ../imgs/validation/$/__1_5060867.png
# [INFO] Moving ../imgs/train/$/__11_7410461.png to ../imgs/validation/$/__11_7410461.png
# [INFO] Moving ../imgs/train/$/__2_9856798.png to ../imgs/validation/$/__2_9856798.png
# [INFO] Moving ../imgs/train/$/__10_8165605.png to ../imgs/validation/$/__10_8165605.png
# [INFO] Moving ../imgs/train/$/__0_6551112.png to ../imgs/validation/$/__0_6551112.png
# [INFO] Moving ../imgs/train/$/__20_3190274.png to ../imgs/validation/$/__20_3190274.png
# [INFO] Moving ../imgs/train/$/__25_8786804.png to ../imgs/validation/$/__25_8786804.png
# [INFO] Moving ../imgs/train/$/__5_6433996.png to ../imgs/validation/$/__5_6433996.png
# [INFO] Moving ../imgs/train/$/__23_6422013.png to ../imgs/validation/$/__23_6422013.png
# [INFO] Moving ../imgs/train/$/__23_3839646.png to ../imgs/validation/$/__23_3839646.png
# [INFO] Moving ../imgs/train/$/__4_3612026.png to ../imgs/validation/$/__4_3612026.png
# [INFO] Moving ../imgs/train/$/__17_9823463.png to ../imgs/validation/$/__17_9823463.png
# [INFO] Moving ../imgs/train/$/__2_2749057.png to ../imgs/validation/$/__2_2749057.png
# [INFO] Moving ../imgs/train/$/__12_6363930.png to ../imgs/validation/$/__12_6363930.png
# [INFO] Moving ../imgs/train/$/__21_6525205.png to ../imgs/validation/$/__21_6525205.png
# [INFO] Moving ../imgs/train/$/__23_5792984.png to ../imgs/validation/$/__23_5792984.png
# [INFO] Moving ../imgs/train/$/__5_1265438.png to ../imgs/validation/$/__5_1265438.png
# [INFO] Moving ../imgs/train/$/__16_4899267.png to ../imgs/validation/$/__16_4899267.png
# [INFO] Moving ../imgs/train/$/__26_5389543.png to ../imgs/validation/$/__26_5389543.png
# [INFO] Moving ../imgs/train/$/__3_8985239.png to ../imgs/validation/$/__3_8985239.png
# [INFO] Moving ../imgs/train/$/__4_3302295.png to ../imgs/validation/$/__4_3302295.png
# [INFO] Moving ../imgs/train/$/__22_67578.png to ../imgs/validation/$/__22_67578.png
# [INFO] Moving ../imgs/train/$/__12_818969.png to ../imgs/validation/$/__12_818969.png
# [INFO] Moving ../imgs/train/$/__12_3726101.png to ../imgs/validation/$/__12_3726101.png
# [INFO] Moving ../imgs/train/$/__23_8090018.png to ../imgs/validation/$/__23_8090018.png
# [INFO] Moving ../imgs/train/$/__19_9453055.png to ../imgs/validation/$/__19_9453055.png
# [INFO] Moving ../imgs/train/$/__11_78581.png to ../imgs/validation/$/__11_78581.png
# [INFO] Moving ../imgs/train/$/__11_3257447.png to ../imgs/validation/$/__11_3257447.png
# [INFO] Moving ../imgs/train/$/__15_5482835.png to ../imgs/validation/$/__15_5482835.png
# [INFO] Moving ../imgs/train/$/__2_8006737.png to ../imgs/validation/$/__2_8006737.png
# [INFO] Moving ../imgs/train/$/__5_4280827.png to ../imgs/validation/$/__5_4280827.png
# [INFO] Moving ../imgs/train/$/__18_4098518.png to ../imgs/validation/$/__18_4098518.png
# [INFO] Moving ../imgs/train/$/__14_2690909.png to ../imgs/validation/$/__14_2690909.png
# [INFO] Moving ../imgs/train/$/__13_8705504.png to ../imgs/validation/$/__13_8705504.png
# [INFO] Moving ../imgs/train/$/__9_7237203.png to ../imgs/validation/$/__9_7237203.png
# [INFO] Moving ../imgs/train/$/__0_8144479.png to ../imgs/validation/$/__0_8144479.png
# [INFO] Moving ../imgs/train/$/__3_4925991.png to ../imgs/validation/$/__3_4925991.png
# [INFO] Moving ../imgs/train/$/__3_1400019.png to ../imgs/validation/$/__3_1400019.png
# [INFO] Moving ../imgs/train/$/__6_7444366.png to ../imgs/validation/$/__6_7444366.png
# [INFO] Moving ../imgs/train/$/__11_4230843.png to ../imgs/validation/$/__11_4230843.png
# [INFO] Moving ../imgs/train/$/__26_7082132.png to ../imgs/validation/$/__26_7082132.png
# [INFO] Moving ../imgs/train/$/__20_3581866.png to ../imgs/validation/$/__20_3581866.png
# [INFO] Moving ../imgs/train/$/__23_9891018.png to ../imgs/validation/$/__23_9891018.png
# [INFO] Moving ../imgs/train/$/__8_7256270.png to ../imgs/validation/$/__8_7256270.png
# [INFO] Moving ../imgs/train/$/__20_4983007.png to ../imgs/validation/$/__20_4983007.png
# [INFO] Moving ../imgs/train/$/__18_6936257.png to ../imgs/validation/$/__18_6936257.png
# [INFO] Moving ../imgs/train/$/__19_5525373.png to ../imgs/validation/$/__19_5525373.png
# [INFO] Moving ../imgs/train/$/__17_6662364.png to ../imgs/validation/$/__17_6662364.png
# [INFO] Moving ../imgs/train/$/__0_9254458.png to ../imgs/validation/$/__0_9254458.png
# [INFO] Moving ../imgs/train/$/__11_447183.png to ../imgs/validation/$/__11_447183.png
# [INFO] Moving ../imgs/train/$/__9_1838043.png to ../imgs/validation/$/__9_1838043.png
# [INFO] Moving ../imgs/train/$/__10_8410086.png to ../imgs/validation/$/__10_8410086.png
# [INFO] Moving ../imgs/train/$/__20_1092059.png to ../imgs/validation/$/__20_1092059.png
# [INFO] Moving ../imgs/train/$/__23_1426181.png to ../imgs/validation/$/__23_1426181.png
# [INFO] Moving ../imgs/train/$/__18_9246878.png to ../imgs/validation/$/__18_9246878.png
# [INFO] Moving ../imgs/train/$/__16_1245228.png to ../imgs/validation/$/__16_1245228.png
# [INFO] Moving ../imgs/train/$/__24_5254655.png to ../imgs/validation/$/__24_5254655.png
# [INFO] Moving ../imgs/train/$/__6_7572756.png to ../imgs/validation/$/__6_7572756.png
# [INFO] Moving ../imgs/train/$/__8_1333323.png to ../imgs/validation/$/__8_1333323.png
# [INFO] Moving ../imgs/train/$/__20_2022831.png to ../imgs/validation/$/__20_2022831.png
# [INFO] Moving ../imgs/train/$/__23_9904072.png to ../imgs/validation/$/__23_9904072.png
# [INFO] Moving ../imgs/train/$/__18_8841021.png to ../imgs/validation/$/__18_8841021.png
# [INFO] Moving ../imgs/train/$/__4_3894470.png to ../imgs/validation/$/__4_3894470.png
# [INFO] Moving ../imgs/train/$/__16_6252188.png to ../imgs/validation/$/__16_6252188.png
# [INFO] Moving ../imgs/train/$/__8_3318849.png to ../imgs/validation/$/__8_3318849.png
# [INFO] Moving ../imgs/train/$/__21_7142086.png to ../imgs/validation/$/__21_7142086.png
# [INFO] Moving ../imgs/train/$/__20_6323936.png to ../imgs/validation/$/__20_6323936.png
# [INFO] Moving ../imgs/train/$/__5_6190599.png to ../imgs/validation/$/__5_6190599.png
# [INFO] Moving ../imgs/train/$/__0_3047911.png to ../imgs/validation/$/__0_3047911.png
# [INFO] Moving ../imgs/train/$/__3_1691261.png to ../imgs/validation/$/__3_1691261.png
# [INFO] Moving ../imgs/train/$/__0_6247766.png to ../imgs/validation/$/__0_6247766.png
# [INFO] Moving ../imgs/train/$/__9_3271629.png to ../imgs/validation/$/__9_3271629.png
# [INFO] Moving ../imgs/train/$/__5_6888459.png to ../imgs/validation/$/__5_6888459.png
# [INFO] Moving ../imgs/train/$/__17_244764.png to ../imgs/validation/$/__17_244764.png
# [INFO] Moving ../imgs/train/$/__7_8864579.png to ../imgs/validation/$/__7_8864579.png
# [INFO] Moving ../imgs/train/$/__8_9835214.png to ../imgs/validation/$/__8_9835214.png
# [INFO] Moving ../imgs/train/$/__4_7567126.png to ../imgs/validation/$/__4_7567126.png
# [INFO] Moving ../imgs/train/$/__11_5456615.png to ../imgs/validation/$/__11_5456615.png
# [INFO] Moving ../imgs/train/$/__9_9430930.png to ../imgs/validation/$/__9_9430930.png
# [INFO] Moving ../imgs/train/$/__6_860390.png to ../imgs/validation/$/__6_860390.png
# [INFO] Moving ../imgs/train/$/__0_3758401.png to ../imgs/validation/$/__0_3758401.png
# [INFO] Moving ../imgs/train/$/__20_5057416.png to ../imgs/validation/$/__20_5057416.png
# [INFO] Moving ../imgs/train/$/__17_7869304.png to ../imgs/validation/$/__17_7869304.png
# [INFO] Moving ../imgs/train/$/__10_3254418.png to ../imgs/validation/$/__10_3254418.png
# [INFO] Moving ../imgs/train/$/__11_272088.png to ../imgs/validation/$/__11_272088.png
# [INFO] Moving ../imgs/train/$/__17_9600537.png to ../imgs/validation/$/__17_9600537.png
# [INFO] Moving ../imgs/train/$/__4_6804810.png to ../imgs/validation/$/__4_6804810.png
# [INFO] Moving ../imgs/train/$/__24_3612526.png to ../imgs/validation/$/__24_3612526.png
# [INFO] Moving ../imgs/train/$/__1_9360052.png to ../imgs/validation/$/__1_9360052.png
# [INFO] Moving ../imgs/train/$/__7_3487204.png to ../imgs/validation/$/__7_3487204.png
# [INFO] Moving ../imgs/train/$/__11_406321.png to ../imgs/validation/$/__11_406321.png
# [INFO] Moving ../imgs/train/$/__9_4534051.png to ../imgs/validation/$/__9_4534051.png
# [INFO] Moving ../imgs/train/$/__22_8726842.png to ../imgs/validation/$/__22_8726842.png
# [INFO] Moving ../imgs/train/$/__0_4388310.png to ../imgs/validation/$/__0_4388310.png
# [INFO] Moving ../imgs/train/$/__0_6476008.png to ../imgs/validation/$/__0_6476008.png
# [INFO] Moving ../imgs/train/$/__13_570659.png to ../imgs/validation/$/__13_570659.png
# [INFO] Moving ../imgs/train/$/__26_3851341.png to ../imgs/validation/$/__26_3851341.png
# [INFO] Moving ../imgs/train/$/__4_8677425.png to ../imgs/validation/$/__4_8677425.png
# [INFO] Moving ../imgs/train/$/__24_5289638.png to ../imgs/validation/$/__24_5289638.png
# [INFO] Moving ../imgs/train/$/__11_8061788.png to ../imgs/validation/$/__11_8061788.png
# [INFO] Moving ../imgs/train/$/__14_3672259.png to ../imgs/validation/$/__14_3672259.png
# [INFO] Moving ../imgs/train/$/__3_8597260.png to ../imgs/validation/$/__3_8597260.png
# [INFO] Moving ../imgs/train/$/__14_1727391.png to ../imgs/validation/$/__14_1727391.png
# [INFO] Moving ../imgs/train/$/__16_3841767.png to ../imgs/validation/$/__16_3841767.png
# [INFO] Moving ../imgs/train/$/__16_7740860.png to ../imgs/validation/$/__16_7740860.png
# [INFO] Moving ../imgs/train/$/__19_8268036.png to ../imgs/validation/$/__19_8268036.png
# [INFO] Moving ../imgs/train/$/__23_5488443.png to ../imgs/validation/$/__23_5488443.png
# [INFO] Moving ../imgs/train/$/__26_2879661.png to ../imgs/validation/$/__26_2879661.png
# [INFO] Moving ../imgs/train/$/__22_6210406.png to ../imgs/validation/$/__22_6210406.png
# [INFO] Moving ../imgs/train/$/__4_3036175.png to ../imgs/validation/$/__4_3036175.png
# [INFO] Moving ../imgs/train/$/__3_8517243.png to ../imgs/validation/$/__3_8517243.png
# [INFO] Moving ../imgs/train/$/__20_3022373.png to ../imgs/validation/$/__20_3022373.png
# [INFO] Moving ../imgs/train/$/__4_3382920.png to ../imgs/validation/$/__4_3382920.png
# [INFO] Moving ../imgs/train/$/__18_9327286.png to ../imgs/validation/$/__18_9327286.png
# [INFO] Moving ../imgs/train/$/__7_5847787.png to ../imgs/validation/$/__7_5847787.png
# [INFO] Moving ../imgs/train/$/__8_3568132.png to ../imgs/validation/$/__8_3568132.png
# [INFO] Moving ../imgs/train/$/__25_875868.png to ../imgs/validation/$/__25_875868.png
# [INFO] Moving ../imgs/train/$/__22_8329739.png to ../imgs/validation/$/__22_8329739.png
# [INFO] Moving ../imgs/train/$/__2_4785361.png to ../imgs/validation/$/__2_4785361.png
# [INFO] Moving ../imgs/train/$/__3_419723.png to ../imgs/validation/$/__3_419723.png
# [INFO] Moving ../imgs/train/$/__18_642966.png to ../imgs/validation/$/__18_642966.png
# [INFO] Moving ../imgs/train/$/__1_6086187.png to ../imgs/validation/$/__1_6086187.png
# [INFO] Moving ../imgs/train/$/__6_2812839.png to ../imgs/validation/$/__6_2812839.png
# [INFO] Moving ../imgs/train/$/__14_7939757.png to ../imgs/validation/$/__14_7939757.png
# [INFO] Moving ../imgs/train/$/__9_6742571.png to ../imgs/validation/$/__9_6742571.png
# [INFO] Moving ../imgs/train/$/__22_1034279.png to ../imgs/validation/$/__22_1034279.png
# [INFO] Moving ../imgs/train/$/__13_9786200.png to ../imgs/validation/$/__13_9786200.png
# [INFO] Moving ../imgs/train/$/__8_9237455.png to ../imgs/validation/$/__8_9237455.png
# [INFO] Moving ../imgs/train/$/__8_8714931.png to ../imgs/validation/$/__8_8714931.png
# [INFO] Moving ../imgs/train/$/__2_502373.png to ../imgs/validation/$/__2_502373.png
# [INFO] Moving ../imgs/train/$/__10_7840839.png to ../imgs/validation/$/__10_7840839.png
# [INFO] Moving ../imgs/train/$/__8_2244312.png to ../imgs/validation/$/__8_2244312.png
# [INFO] Moving ../imgs/train/$/__1_1382167.png to ../imgs/validation/$/__1_1382167.png
# [INFO] Moving ../imgs/train/$/__25_8683061.png to ../imgs/validation/$/__25_8683061.png
# [INFO] Moving ../imgs/train/$/__6_390626.png to ../imgs/validation/$/__6_390626.png
# [INFO] Moving ../imgs/train/$/__18_8447702.png to ../imgs/validation/$/__18_8447702.png
# [INFO] Moving ../imgs/train/$/__10_2091258.png to ../imgs/validation/$/__10_2091258.png
# [INFO] Moving ../imgs/train/$/__13_5836224.png to ../imgs/validation/$/__13_5836224.png
# [INFO] Moving ../imgs/train/$/__4_4475803.png to ../imgs/validation/$/__4_4475803.png
# [INFO] Moving ../imgs/train/$/__7_8673579.png to ../imgs/validation/$/__7_8673579.png
# [INFO] Moving ../imgs/train/$/__19_7253267.png to ../imgs/validation/$/__19_7253267.png
# [INFO] Moving ../imgs/train/$/__22_4028427.png to ../imgs/validation/$/__22_4028427.png
# [INFO] Moving ../imgs/train/$/__20_2371074.png to ../imgs/validation/$/__20_2371074.png
# [INFO] Moving ../imgs/train/$/__24_3978434.png to ../imgs/validation/$/__24_3978434.png
# [INFO] Moving ../imgs/train/$/__6_921988.png to ../imgs/validation/$/__6_921988.png
# [INFO] Moving ../imgs/train/$/__1_819076.png to ../imgs/validation/$/__1_819076.png
# [INFO] Moving ../imgs/train/$/__25_1167474.png to ../imgs/validation/$/__25_1167474.png
# [INFO] Moving ../imgs/train/$/__6_2988054.png to ../imgs/validation/$/__6_2988054.png
# [INFO] Moving ../imgs/train/$/__6_3494316.png to ../imgs/validation/$/__6_3494316.png
# [INFO] Moving ../imgs/train/$/__2_5960708.png to ../imgs/validation/$/__2_5960708.png
# [INFO] Moving ../imgs/train/$/__15_9940706.png to ../imgs/validation/$/__15_9940706.png
# [INFO] Moving ../imgs/train/$/__16_9538001.png to ../imgs/validation/$/__16_9538001.png
# [INFO] Moving ../imgs/train/$/__8_6246663.png to ../imgs/validation/$/__8_6246663.png
# [INFO] Moving ../imgs/train/$/__21_9492761.png to ../imgs/validation/$/__21_9492761.png
# 32
# [INFO] Moving ../imgs/train/)/23888.png to ../imgs/validation/)/23888.png
# [INFO] Moving ../imgs/train/)/58010.png to ../imgs/validation/)/58010.png
# [INFO] Moving ../imgs/train/)/30771.png to ../imgs/validation/)/30771.png
# [INFO] Moving ../imgs/train/)/43429.png to ../imgs/validation/)/43429.png
# [INFO] Moving ../imgs/train/)/33891.png to ../imgs/validation/)/33891.png
# [INFO] Moving ../imgs/train/)/30577.png to ../imgs/validation/)/30577.png
# [INFO] Moving ../imgs/train/)/49947.png to ../imgs/validation/)/49947.png
# [INFO] Moving ../imgs/train/)/50655.png to ../imgs/validation/)/50655.png
# [INFO] Moving ../imgs/train/)/54333.png to ../imgs/validation/)/54333.png
# [INFO] Moving ../imgs/train/)/47985.png to ../imgs/validation/)/47985.png
# [INFO] Moving ../imgs/train/)/61041.png to ../imgs/validation/)/61041.png
# [INFO] Moving ../imgs/train/)/19981.png to ../imgs/validation/)/19981.png
# [INFO] Moving ../imgs/train/)/20403.png to ../imgs/validation/)/20403.png
# [INFO] Moving ../imgs/train/)/36261.png to ../imgs/validation/)/36261.png
# [INFO] Moving ../imgs/train/)/56763.png to ../imgs/validation/)/56763.png
# [INFO] Moving ../imgs/train/)/12877.png to ../imgs/validation/)/12877.png
# [INFO] Moving ../imgs/train/)/43260.png to ../imgs/validation/)/43260.png
# [INFO] Moving ../imgs/train/)/10916.png to ../imgs/validation/)/10916.png
# [INFO] Moving ../imgs/train/)/61044.png to ../imgs/validation/)/61044.png
# [INFO] Moving ../imgs/train/)/36080.png to ../imgs/validation/)/36080.png
# [INFO] Moving ../imgs/train/)/47866.png to ../imgs/validation/)/47866.png
# [INFO] Moving ../imgs/train/)/22501.png to ../imgs/validation/)/22501.png
# [INFO] Moving ../imgs/train/)/42275.png to ../imgs/validation/)/42275.png
# [INFO] Moving ../imgs/train/)/22462.png to ../imgs/validation/)/22462.png
# [INFO] Moving ../imgs/train/)/49198.png to ../imgs/validation/)/49198.png
# [INFO] Moving ../imgs/train/)/33885.png to ../imgs/validation/)/33885.png
# [INFO] Moving ../imgs/train/)/44396.png to ../imgs/validation/)/44396.png
# [INFO] Moving ../imgs/train/)/15834.png to ../imgs/validation/)/15834.png
# [INFO] Moving ../imgs/train/)/36086.png to ../imgs/validation/)/36086.png
# [INFO] Moving ../imgs/train/)/37123.png to ../imgs/validation/)/37123.png
# [INFO] Moving ../imgs/train/)/60679.png to ../imgs/validation/)/60679.png
# [INFO] Moving ../imgs/train/)/50344.png to ../imgs/validation/)/50344.png
# 245
# [INFO] Moving ../imgs/train/L/EMNIST_36646.png to ../imgs/validation/L/EMNIST_36646.png
# [INFO] Moving ../imgs/train/L/EMNIST_91011.png to ../imgs/validation/L/EMNIST_91011.png
# [INFO] Moving ../imgs/train/L/EMNIST_71751.png to ../imgs/validation/L/EMNIST_71751.png
# [INFO] Moving ../imgs/train/L/EMNIST_81842.png to ../imgs/validation/L/EMNIST_81842.png
# [INFO] Moving ../imgs/train/L/EMNIST_65056.png to ../imgs/validation/L/EMNIST_65056.png
# [INFO] Moving ../imgs/train/L/EMNIST_76833.png to ../imgs/validation/L/EMNIST_76833.png
# [INFO] Moving ../imgs/train/L/EMNIST_95078.png to ../imgs/validation/L/EMNIST_95078.png
# [INFO] Moving ../imgs/train/L/EMNIST_64879.png to ../imgs/validation/L/EMNIST_64879.png
# [INFO] Moving ../imgs/train/L/EMNIST_66836.png to ../imgs/validation/L/EMNIST_66836.png
# [INFO] Moving ../imgs/train/L/EMNIST_95786.png to ../imgs/validation/L/EMNIST_95786.png
# [INFO] Moving ../imgs/train/L/EMNIST_3300.png to ../imgs/validation/L/EMNIST_3300.png
# [INFO] Moving ../imgs/train/L/EMNIST_15455.png to ../imgs/validation/L/EMNIST_15455.png
# [INFO] Moving ../imgs/train/L/EMNIST_4948.png to ../imgs/validation/L/EMNIST_4948.png
# [INFO] Moving ../imgs/train/L/EMNIST_94933.png to ../imgs/validation/L/EMNIST_94933.png
# [INFO] Moving ../imgs/train/L/EMNIST_48797.png to ../imgs/validation/L/EMNIST_48797.png
# [INFO] Moving ../imgs/train/L/EMNIST_98887.png to ../imgs/validation/L/EMNIST_98887.png
# [INFO] Moving ../imgs/train/L/EMNIST_29991.png to ../imgs/validation/L/EMNIST_29991.png
# [INFO] Moving ../imgs/train/L/EMNIST_85958.png to ../imgs/validation/L/EMNIST_85958.png
# [INFO] Moving ../imgs/train/L/EMNIST_67073.png to ../imgs/validation/L/EMNIST_67073.png
# [INFO] Moving ../imgs/train/L/EMNIST_28785.png to ../imgs/validation/L/EMNIST_28785.png
# [INFO] Moving ../imgs/train/L/EMNIST_66168.png to ../imgs/validation/L/EMNIST_66168.png
# [INFO] Moving ../imgs/train/L/EMNIST_2272.png to ../imgs/validation/L/EMNIST_2272.png
# [INFO] Moving ../imgs/train/L/EMNIST_32622.png to ../imgs/validation/L/EMNIST_32622.png
# [INFO] Moving ../imgs/train/L/EMNIST_65503.png to ../imgs/validation/L/EMNIST_65503.png
# [INFO] Moving ../imgs/train/L/EMNIST_101400.png to ../imgs/validation/L/EMNIST_101400.png
# [INFO] Moving ../imgs/train/L/EMNIST_20290.png to ../imgs/validation/L/EMNIST_20290.png
# [INFO] Moving ../imgs/train/L/EMNIST_50254.png to ../imgs/validation/L/EMNIST_50254.png
# [INFO] Moving ../imgs/train/L/EMNIST_61413.png to ../imgs/validation/L/EMNIST_61413.png
# [INFO] Moving ../imgs/train/L/EMNIST_25760.png to ../imgs/validation/L/EMNIST_25760.png
# [INFO] Moving ../imgs/train/L/EMNIST_18110.png to ../imgs/validation/L/EMNIST_18110.png
# [INFO] Moving ../imgs/train/L/EMNIST_34413.png to ../imgs/validation/L/EMNIST_34413.png
# [INFO] Moving ../imgs/train/L/EMNIST_36618.png to ../imgs/validation/L/EMNIST_36618.png
# [INFO] Moving ../imgs/train/L/EMNIST_30468.png to ../imgs/validation/L/EMNIST_30468.png
# [INFO] Moving ../imgs/train/L/EMNIST_9030.png to ../imgs/validation/L/EMNIST_9030.png
# [INFO] Moving ../imgs/train/L/EMNIST_109565.png to ../imgs/validation/L/EMNIST_109565.png
# [INFO] Moving ../imgs/train/L/EMNIST_51807.png to ../imgs/validation/L/EMNIST_51807.png
# [INFO] Moving ../imgs/train/L/EMNIST_88260.png to ../imgs/validation/L/EMNIST_88260.png
# [INFO] Moving ../imgs/train/L/EMNIST_76557.png to ../imgs/validation/L/EMNIST_76557.png
# [INFO] Moving ../imgs/train/L/EMNIST_59725.png to ../imgs/validation/L/EMNIST_59725.png
# [INFO] Moving ../imgs/train/L/EMNIST_67861.png to ../imgs/validation/L/EMNIST_67861.png
# [INFO] Moving ../imgs/train/L/EMNIST_41631.png to ../imgs/validation/L/EMNIST_41631.png
# [INFO] Moving ../imgs/train/L/EMNIST_31897.png to ../imgs/validation/L/EMNIST_31897.png
# [INFO] Moving ../imgs/train/L/EMNIST_21074.png to ../imgs/validation/L/EMNIST_21074.png
# [INFO] Moving ../imgs/train/L/EMNIST_90608.png to ../imgs/validation/L/EMNIST_90608.png
# [INFO] Moving ../imgs/train/L/EMNIST_78580.png to ../imgs/validation/L/EMNIST_78580.png
# [INFO] Moving ../imgs/train/L/EMNIST_81149.png to ../imgs/validation/L/EMNIST_81149.png
# [INFO] Moving ../imgs/train/L/EMNIST_2471.png to ../imgs/validation/L/EMNIST_2471.png
# [INFO] Moving ../imgs/train/L/EMNIST_55071.png to ../imgs/validation/L/EMNIST_55071.png
# [INFO] Moving ../imgs/train/L/EMNIST_4449.png to ../imgs/validation/L/EMNIST_4449.png
# [INFO] Moving ../imgs/train/L/EMNIST_46683.png to ../imgs/validation/L/EMNIST_46683.png
# [INFO] Moving ../imgs/train/L/EMNIST_78955.png to ../imgs/validation/L/EMNIST_78955.png
# [INFO] Moving ../imgs/train/L/EMNIST_101366.png to ../imgs/validation/L/EMNIST_101366.png
# [INFO] Moving ../imgs/train/L/EMNIST_110273.png to ../imgs/validation/L/EMNIST_110273.png
# [INFO] Moving ../imgs/train/L/EMNIST_68621.png to ../imgs/validation/L/EMNIST_68621.png
# [INFO] Moving ../imgs/train/L/EMNIST_56930.png to ../imgs/validation/L/EMNIST_56930.png
# [INFO] Moving ../imgs/train/L/EMNIST_75637.png to ../imgs/validation/L/EMNIST_75637.png
# [INFO] Moving ../imgs/train/L/EMNIST_80079.png to ../imgs/validation/L/EMNIST_80079.png
# [INFO] Moving ../imgs/train/L/EMNIST_26535.png to ../imgs/validation/L/EMNIST_26535.png
# [INFO] Moving ../imgs/train/L/EMNIST_104151.png to ../imgs/validation/L/EMNIST_104151.png
# [INFO] Moving ../imgs/train/L/EMNIST_36395.png to ../imgs/validation/L/EMNIST_36395.png
# [INFO] Moving ../imgs/train/L/Hnd_img022-020.png to ../imgs/validation/L/Hnd_img022-020.png
# [INFO] Moving ../imgs/train/L/EMNIST_74352.png to ../imgs/validation/L/EMNIST_74352.png
# [INFO] Moving ../imgs/train/L/EMNIST_35388.png to ../imgs/validation/L/EMNIST_35388.png
# [INFO] Moving ../imgs/train/L/EMNIST_4701.png to ../imgs/validation/L/EMNIST_4701.png
# [INFO] Moving ../imgs/train/L/Hnd_img022-010.png to ../imgs/validation/L/Hnd_img022-010.png
# [INFO] Moving ../imgs/train/L/EMNIST_34331.png to ../imgs/validation/L/EMNIST_34331.png
# [INFO] Moving ../imgs/train/L/EMNIST_95210.png to ../imgs/validation/L/EMNIST_95210.png
# [INFO] Moving ../imgs/train/L/EMNIST_72823.png to ../imgs/validation/L/EMNIST_72823.png
# [INFO] Moving ../imgs/train/L/EMNIST_7030.png to ../imgs/validation/L/EMNIST_7030.png
# [INFO] Moving ../imgs/train/L/EMNIST_106825.png to ../imgs/validation/L/EMNIST_106825.png
# [INFO] Moving ../imgs/train/L/EMNIST_77579.png to ../imgs/validation/L/EMNIST_77579.png
# [INFO] Moving ../imgs/train/L/EMNIST_33432.png to ../imgs/validation/L/EMNIST_33432.png
# [INFO] Moving ../imgs/train/L/EMNIST_95486.png to ../imgs/validation/L/EMNIST_95486.png
# [INFO] Moving ../imgs/train/L/EMNIST_71111.png to ../imgs/validation/L/EMNIST_71111.png
# [INFO] Moving ../imgs/train/L/EMNIST_12623.png to ../imgs/validation/L/EMNIST_12623.png
# [INFO] Moving ../imgs/train/L/EMNIST_88610.png to ../imgs/validation/L/EMNIST_88610.png
# [INFO] Moving ../imgs/train/L/EMNIST_64348.png to ../imgs/validation/L/EMNIST_64348.png
# [INFO] Moving ../imgs/train/L/EMNIST_40310.png to ../imgs/validation/L/EMNIST_40310.png
# [INFO] Moving ../imgs/train/L/EMNIST_23351.png to ../imgs/validation/L/EMNIST_23351.png
# [INFO] Moving ../imgs/train/L/EMNIST_4098.png to ../imgs/validation/L/EMNIST_4098.png
# [INFO] Moving ../imgs/train/L/EMNIST_107333.png to ../imgs/validation/L/EMNIST_107333.png
# [INFO] Moving ../imgs/train/L/EMNIST_84202.png to ../imgs/validation/L/EMNIST_84202.png
# [INFO] Moving ../imgs/train/L/EMNIST_77678.png to ../imgs/validation/L/EMNIST_77678.png
# [INFO] Moving ../imgs/train/L/EMNIST_69026.png to ../imgs/validation/L/EMNIST_69026.png
# [INFO] Moving ../imgs/train/L/EMNIST_9733.png to ../imgs/validation/L/EMNIST_9733.png
# [INFO] Moving ../imgs/train/L/EMNIST_29291.png to ../imgs/validation/L/EMNIST_29291.png
# [INFO] Moving ../imgs/train/L/EMNIST_7043.png to ../imgs/validation/L/EMNIST_7043.png
# [INFO] Moving ../imgs/train/L/EMNIST_19310.png to ../imgs/validation/L/EMNIST_19310.png
# [INFO] Moving ../imgs/train/L/EMNIST_86472.png to ../imgs/validation/L/EMNIST_86472.png
# [INFO] Moving ../imgs/train/L/EMNIST_60250.png to ../imgs/validation/L/EMNIST_60250.png
# [INFO] Moving ../imgs/train/L/EMNIST_87316.png to ../imgs/validation/L/EMNIST_87316.png
# [INFO] Moving ../imgs/train/L/EMNIST_58635.png to ../imgs/validation/L/EMNIST_58635.png
# [INFO] Moving ../imgs/train/L/EMNIST_55542.png to ../imgs/validation/L/EMNIST_55542.png
# [INFO] Moving ../imgs/train/L/EMNIST_37059.png to ../imgs/validation/L/EMNIST_37059.png
# [INFO] Moving ../imgs/train/L/EMNIST_63059.png to ../imgs/validation/L/EMNIST_63059.png
# [INFO] Moving ../imgs/train/L/EMNIST_32380.png to ../imgs/validation/L/EMNIST_32380.png
# [INFO] Moving ../imgs/train/L/EMNIST_28879.png to ../imgs/validation/L/EMNIST_28879.png
# [INFO] Moving ../imgs/train/L/EMNIST_37861.png to ../imgs/validation/L/EMNIST_37861.png
# [INFO] Moving ../imgs/train/L/EMNIST_75135.png to ../imgs/validation/L/EMNIST_75135.png
# [INFO] Moving ../imgs/train/L/EMNIST_69285.png to ../imgs/validation/L/EMNIST_69285.png
# [INFO] Moving ../imgs/train/L/EMNIST_70195.png to ../imgs/validation/L/EMNIST_70195.png
# [INFO] Moving ../imgs/train/L/EMNIST_50029.png to ../imgs/validation/L/EMNIST_50029.png
# [INFO] Moving ../imgs/train/L/EMNIST_51342.png to ../imgs/validation/L/EMNIST_51342.png
# [INFO] Moving ../imgs/train/L/EMNIST_96084.png to ../imgs/validation/L/EMNIST_96084.png
# [INFO] Moving ../imgs/train/L/EMNIST_61455.png to ../imgs/validation/L/EMNIST_61455.png
# [INFO] Moving ../imgs/train/L/EMNIST_50542.png to ../imgs/validation/L/EMNIST_50542.png
# [INFO] Moving ../imgs/train/L/EMNIST_16788.png to ../imgs/validation/L/EMNIST_16788.png
# [INFO] Moving ../imgs/train/L/EMNIST_105747.png to ../imgs/validation/L/EMNIST_105747.png
# [INFO] Moving ../imgs/train/L/EMNIST_33290.png to ../imgs/validation/L/EMNIST_33290.png
# [INFO] Moving ../imgs/train/L/EMNIST_14400.png to ../imgs/validation/L/EMNIST_14400.png
# [INFO] Moving ../imgs/train/L/EMNIST_7518.png to ../imgs/validation/L/EMNIST_7518.png
# [INFO] Moving ../imgs/train/L/EMNIST_102071.png to ../imgs/validation/L/EMNIST_102071.png
# [INFO] Moving ../imgs/train/L/EMNIST_91284.png to ../imgs/validation/L/EMNIST_91284.png
# [INFO] Moving ../imgs/train/L/EMNIST_81949.png to ../imgs/validation/L/EMNIST_81949.png
# [INFO] Moving ../imgs/train/L/EMNIST_54921.png to ../imgs/validation/L/EMNIST_54921.png
# [INFO] Moving ../imgs/train/L/EMNIST_23620.png to ../imgs/validation/L/EMNIST_23620.png
# [INFO] Moving ../imgs/train/L/EMNIST_4143.png to ../imgs/validation/L/EMNIST_4143.png
# [INFO] Moving ../imgs/train/L/EMNIST_17705.png to ../imgs/validation/L/EMNIST_17705.png
# [INFO] Moving ../imgs/train/L/EMNIST_44276.png to ../imgs/validation/L/EMNIST_44276.png
# [INFO] Moving ../imgs/train/L/EMNIST_71902.png to ../imgs/validation/L/EMNIST_71902.png
# [INFO] Moving ../imgs/train/L/EMNIST_36742.png to ../imgs/validation/L/EMNIST_36742.png
# [INFO] Moving ../imgs/train/L/EMNIST_7118.png to ../imgs/validation/L/EMNIST_7118.png
# [INFO] Moving ../imgs/train/L/EMNIST_81704.png to ../imgs/validation/L/EMNIST_81704.png
# [INFO] Moving ../imgs/train/L/EMNIST_76350.png to ../imgs/validation/L/EMNIST_76350.png
# [INFO] Moving ../imgs/train/L/EMNIST_60872.png to ../imgs/validation/L/EMNIST_60872.png
# [INFO] Moving ../imgs/train/L/EMNIST_36859.png to ../imgs/validation/L/EMNIST_36859.png
# [INFO] Moving ../imgs/train/L/EMNIST_58558.png to ../imgs/validation/L/EMNIST_58558.png
# [INFO] Moving ../imgs/train/L/EMNIST_85580.png to ../imgs/validation/L/EMNIST_85580.png
# [INFO] Moving ../imgs/train/L/EMNIST_44360.png to ../imgs/validation/L/EMNIST_44360.png
# [INFO] Moving ../imgs/train/L/EMNIST_79217.png to ../imgs/validation/L/EMNIST_79217.png
# [INFO] Moving ../imgs/train/L/EMNIST_108342.png to ../imgs/validation/L/EMNIST_108342.png
# [INFO] Moving ../imgs/train/L/EMNIST_26054.png to ../imgs/validation/L/EMNIST_26054.png
# [INFO] Moving ../imgs/train/L/EMNIST_12212.png to ../imgs/validation/L/EMNIST_12212.png
# [INFO] Moving ../imgs/train/L/EMNIST_108302.png to ../imgs/validation/L/EMNIST_108302.png
# [INFO] Moving ../imgs/train/L/EMNIST_33009.png to ../imgs/validation/L/EMNIST_33009.png
# [INFO] Moving ../imgs/train/L/EMNIST_2269.png to ../imgs/validation/L/EMNIST_2269.png
# [INFO] Moving ../imgs/train/L/EMNIST_33317.png to ../imgs/validation/L/EMNIST_33317.png
# [INFO] Moving ../imgs/train/L/EMNIST_96724.png to ../imgs/validation/L/EMNIST_96724.png
# [INFO] Moving ../imgs/train/L/EMNIST_17355.png to ../imgs/validation/L/EMNIST_17355.png
# [INFO] Moving ../imgs/train/L/EMNIST_34471.png to ../imgs/validation/L/EMNIST_34471.png
# [INFO] Moving ../imgs/train/L/EMNIST_102438.png to ../imgs/validation/L/EMNIST_102438.png
# [INFO] Moving ../imgs/train/L/EMNIST_104762.png to ../imgs/validation/L/EMNIST_104762.png
# [INFO] Moving ../imgs/train/L/EMNIST_109675.png to ../imgs/validation/L/EMNIST_109675.png
# [INFO] Moving ../imgs/train/L/EMNIST_49297.png to ../imgs/validation/L/EMNIST_49297.png
# [INFO] Moving ../imgs/train/L/EMNIST_9026.png to ../imgs/validation/L/EMNIST_9026.png
# [INFO] Moving ../imgs/train/L/EMNIST_4584.png to ../imgs/validation/L/EMNIST_4584.png
# [INFO] Moving ../imgs/train/L/EMNIST_40784.png to ../imgs/validation/L/EMNIST_40784.png
# [INFO] Moving ../imgs/train/L/EMNIST_20872.png to ../imgs/validation/L/EMNIST_20872.png
# [INFO] Moving ../imgs/train/L/EMNIST_10628.png to ../imgs/validation/L/EMNIST_10628.png
# [INFO] Moving ../imgs/train/L/EMNIST_11651.png to ../imgs/validation/L/EMNIST_11651.png
# [INFO] Moving ../imgs/train/L/EMNIST_95037.png to ../imgs/validation/L/EMNIST_95037.png
# [INFO] Moving ../imgs/train/L/EMNIST_54664.png to ../imgs/validation/L/EMNIST_54664.png
# [INFO] Moving ../imgs/train/L/EMNIST_51544.png to ../imgs/validation/L/EMNIST_51544.png
# [INFO] Moving ../imgs/train/L/EMNIST_72964.png to ../imgs/validation/L/EMNIST_72964.png
# [INFO] Moving ../imgs/train/L/EMNIST_103834.png to ../imgs/validation/L/EMNIST_103834.png
# [INFO] Moving ../imgs/train/L/EMNIST_88968.png to ../imgs/validation/L/EMNIST_88968.png
# [INFO] Moving ../imgs/train/L/EMNIST_78050.png to ../imgs/validation/L/EMNIST_78050.png
# [INFO] Moving ../imgs/train/L/EMNIST_99393.png to ../imgs/validation/L/EMNIST_99393.png
# [INFO] Moving ../imgs/train/L/EMNIST_46835.png to ../imgs/validation/L/EMNIST_46835.png
# [INFO] Moving ../imgs/train/L/EMNIST_110752.png to ../imgs/validation/L/EMNIST_110752.png
# [INFO] Moving ../imgs/train/L/EMNIST_48425.png to ../imgs/validation/L/EMNIST_48425.png
# [INFO] Moving ../imgs/train/L/EMNIST_79926.png to ../imgs/validation/L/EMNIST_79926.png
# [INFO] Moving ../imgs/train/L/EMNIST_62097.png to ../imgs/validation/L/EMNIST_62097.png
# [INFO] Moving ../imgs/train/L/EMNIST_100751.png to ../imgs/validation/L/EMNIST_100751.png
# [INFO] Moving ../imgs/train/L/EMNIST_18058.png to ../imgs/validation/L/EMNIST_18058.png
# [INFO] Moving ../imgs/train/L/EMNIST_59693.png to ../imgs/validation/L/EMNIST_59693.png
# [INFO] Moving ../imgs/train/L/EMNIST_29126.png to ../imgs/validation/L/EMNIST_29126.png
# [INFO] Moving ../imgs/train/L/EMNIST_53249.png to ../imgs/validation/L/EMNIST_53249.png
# [INFO] Moving ../imgs/train/L/EMNIST_50160.png to ../imgs/validation/L/EMNIST_50160.png
# [INFO] Moving ../imgs/train/L/EMNIST_34191.png to ../imgs/validation/L/EMNIST_34191.png
# [INFO] Moving ../imgs/train/L/EMNIST_104008.png to ../imgs/validation/L/EMNIST_104008.png
# [INFO] Moving ../imgs/train/L/EMNIST_1534.png to ../imgs/validation/L/EMNIST_1534.png
# [INFO] Moving ../imgs/train/L/EMNIST_10041.png to ../imgs/validation/L/EMNIST_10041.png
# [INFO] Moving ../imgs/train/L/EMNIST_93693.png to ../imgs/validation/L/EMNIST_93693.png
# [INFO] Moving ../imgs/train/L/EMNIST_26785.png to ../imgs/validation/L/EMNIST_26785.png
# [INFO] Moving ../imgs/train/L/EMNIST_45127.png to ../imgs/validation/L/EMNIST_45127.png
# [INFO] Moving ../imgs/train/L/EMNIST_29048.png to ../imgs/validation/L/EMNIST_29048.png
# [INFO] Moving ../imgs/train/L/EMNIST_26141.png to ../imgs/validation/L/EMNIST_26141.png
# [INFO] Moving ../imgs/train/L/Hnd_img022-024.png to ../imgs/validation/L/Hnd_img022-024.png
# [INFO] Moving ../imgs/train/L/EMNIST_78857.png to ../imgs/validation/L/EMNIST_78857.png
# [INFO] Moving ../imgs/train/L/EMNIST_58953.png to ../imgs/validation/L/EMNIST_58953.png
# [INFO] Moving ../imgs/train/L/EMNIST_47251.png to ../imgs/validation/L/EMNIST_47251.png
# [INFO] Moving ../imgs/train/L/EMNIST_68369.png to ../imgs/validation/L/EMNIST_68369.png
# [INFO] Moving ../imgs/train/L/EMNIST_34515.png to ../imgs/validation/L/EMNIST_34515.png
# [INFO] Moving ../imgs/train/L/EMNIST_27455.png to ../imgs/validation/L/EMNIST_27455.png
# [INFO] Moving ../imgs/train/L/EMNIST_101702.png to ../imgs/validation/L/EMNIST_101702.png
# [INFO] Moving ../imgs/train/L/EMNIST_94480.png to ../imgs/validation/L/EMNIST_94480.png
# [INFO] Moving ../imgs/train/L/EMNIST_18990.png to ../imgs/validation/L/EMNIST_18990.png
# [INFO] Moving ../imgs/train/L/EMNIST_27602.png to ../imgs/validation/L/EMNIST_27602.png
# [INFO] Moving ../imgs/train/L/EMNIST_105071.png to ../imgs/validation/L/EMNIST_105071.png
# [INFO] Moving ../imgs/train/L/EMNIST_59110.png to ../imgs/validation/L/EMNIST_59110.png
# [INFO] Moving ../imgs/train/L/EMNIST_110067.png to ../imgs/validation/L/EMNIST_110067.png
# [INFO] Moving ../imgs/train/L/EMNIST_12969.png to ../imgs/validation/L/EMNIST_12969.png
# [INFO] Moving ../imgs/train/L/EMNIST_55640.png to ../imgs/validation/L/EMNIST_55640.png
# [INFO] Moving ../imgs/train/L/EMNIST_31647.png to ../imgs/validation/L/EMNIST_31647.png
# [INFO] Moving ../imgs/train/L/EMNIST_10133.png to ../imgs/validation/L/EMNIST_10133.png
# [INFO] Moving ../imgs/train/L/EMNIST_63170.png to ../imgs/validation/L/EMNIST_63170.png
# [INFO] Moving ../imgs/train/L/EMNIST_16706.png to ../imgs/validation/L/EMNIST_16706.png
# [INFO] Moving ../imgs/train/L/EMNIST_78277.png to ../imgs/validation/L/EMNIST_78277.png
# [INFO] Moving ../imgs/train/L/EMNIST_66163.png to ../imgs/validation/L/EMNIST_66163.png
# [INFO] Moving ../imgs/train/L/EMNIST_94764.png to ../imgs/validation/L/EMNIST_94764.png
# [INFO] Moving ../imgs/train/L/EMNIST_91951.png to ../imgs/validation/L/EMNIST_91951.png
# [INFO] Moving ../imgs/train/L/EMNIST_83314.png to ../imgs/validation/L/EMNIST_83314.png
# [INFO] Moving ../imgs/train/L/EMNIST_24010.png to ../imgs/validation/L/EMNIST_24010.png
# [INFO] Moving ../imgs/train/L/EMNIST_75646.png to ../imgs/validation/L/EMNIST_75646.png
# [INFO] Moving ../imgs/train/L/EMNIST_75034.png to ../imgs/validation/L/EMNIST_75034.png
# [INFO] Moving ../imgs/train/L/EMNIST_34690.png to ../imgs/validation/L/EMNIST_34690.png
# [INFO] Moving ../imgs/train/L/EMNIST_6501.png to ../imgs/validation/L/EMNIST_6501.png
# [INFO] Moving ../imgs/train/L/EMNIST_809.png to ../imgs/validation/L/EMNIST_809.png
# [INFO] Moving ../imgs/train/L/EMNIST_51003.png to ../imgs/validation/L/EMNIST_51003.png
# [INFO] Moving ../imgs/train/L/EMNIST_2942.png to ../imgs/validation/L/EMNIST_2942.png
# [INFO] Moving ../imgs/train/L/EMNIST_92948.png to ../imgs/validation/L/EMNIST_92948.png
# [INFO] Moving ../imgs/train/L/EMNIST_75278.png to ../imgs/validation/L/EMNIST_75278.png
# [INFO] Moving ../imgs/train/L/EMNIST_13549.png to ../imgs/validation/L/EMNIST_13549.png
# [INFO] Moving ../imgs/train/L/EMNIST_15495.png to ../imgs/validation/L/EMNIST_15495.png
# [INFO] Moving ../imgs/train/L/EMNIST_28477.png to ../imgs/validation/L/EMNIST_28477.png
# [INFO] Moving ../imgs/train/L/EMNIST_773.png to ../imgs/validation/L/EMNIST_773.png
# [INFO] Moving ../imgs/train/L/EMNIST_69838.png to ../imgs/validation/L/EMNIST_69838.png
# [INFO] Moving ../imgs/train/L/EMNIST_16724.png to ../imgs/validation/L/EMNIST_16724.png
# [INFO] Moving ../imgs/train/L/EMNIST_34375.png to ../imgs/validation/L/EMNIST_34375.png
# [INFO] Moving ../imgs/train/L/EMNIST_31812.png to ../imgs/validation/L/EMNIST_31812.png
# [INFO] Moving ../imgs/train/L/EMNIST_81155.png to ../imgs/validation/L/EMNIST_81155.png
# [INFO] Moving ../imgs/train/L/EMNIST_94403.png to ../imgs/validation/L/EMNIST_94403.png
# [INFO] Moving ../imgs/train/L/EMNIST_611.png to ../imgs/validation/L/EMNIST_611.png
# [INFO] Moving ../imgs/train/L/EMNIST_51691.png to ../imgs/validation/L/EMNIST_51691.png
# [INFO] Moving ../imgs/train/L/EMNIST_90402.png to ../imgs/validation/L/EMNIST_90402.png
# [INFO] Moving ../imgs/train/L/EMNIST_26138.png to ../imgs/validation/L/EMNIST_26138.png
# [INFO] Moving ../imgs/train/L/EMNIST_39601.png to ../imgs/validation/L/EMNIST_39601.png
# [INFO] Moving ../imgs/train/L/EMNIST_9723.png to ../imgs/validation/L/EMNIST_9723.png
# [INFO] Moving ../imgs/train/L/EMNIST_38813.png to ../imgs/validation/L/EMNIST_38813.png
# [INFO] Moving ../imgs/train/L/EMNIST_52157.png to ../imgs/validation/L/EMNIST_52157.png
# [INFO] Moving ../imgs/train/L/EMNIST_87170.png to ../imgs/validation/L/EMNIST_87170.png
# [INFO] Moving ../imgs/train/L/EMNIST_98486.png to ../imgs/validation/L/EMNIST_98486.png
# [INFO] Moving ../imgs/train/L/EMNIST_43431.png to ../imgs/validation/L/EMNIST_43431.png
# [INFO] Moving ../imgs/train/L/EMNIST_98130.png to ../imgs/validation/L/EMNIST_98130.png
# [INFO] Moving ../imgs/train/L/EMNIST_3524.png to ../imgs/validation/L/EMNIST_3524.png
# [INFO] Moving ../imgs/train/L/EMNIST_19997.png to ../imgs/validation/L/EMNIST_19997.png
# [INFO] Moving ../imgs/train/L/EMNIST_31431.png to ../imgs/validation/L/EMNIST_31431.png
# [INFO] Moving ../imgs/train/L/EMNIST_112020.png to ../imgs/validation/L/EMNIST_112020.png
# [INFO] Moving ../imgs/train/L/EMNIST_28263.png to ../imgs/validation/L/EMNIST_28263.png
# [INFO] Moving ../imgs/train/L/EMNIST_110702.png to ../imgs/validation/L/EMNIST_110702.png
# [INFO] Moving ../imgs/train/L/EMNIST_60648.png to ../imgs/validation/L/EMNIST_60648.png
# [INFO] Moving ../imgs/train/L/EMNIST_18666.png to ../imgs/validation/L/EMNIST_18666.png
# [INFO] Moving ../imgs/train/L/EMNIST_108005.png to ../imgs/validation/L/EMNIST_108005.png
# [INFO] Moving ../imgs/train/L/EMNIST_28395.png to ../imgs/validation/L/EMNIST_28395.png
# 245
# [INFO] Moving ../imgs/train/H/EMNIST_17190.png to ../imgs/validation/H/EMNIST_17190.png
# [INFO] Moving ../imgs/train/H/EMNIST_68225.png to ../imgs/validation/H/EMNIST_68225.png
# [INFO] Moving ../imgs/train/H/EMNIST_40313.png to ../imgs/validation/H/EMNIST_40313.png
# [INFO] Moving ../imgs/train/H/EMNIST_4438.png to ../imgs/validation/H/EMNIST_4438.png
# [INFO] Moving ../imgs/train/H/EMNIST_50463.png to ../imgs/validation/H/EMNIST_50463.png
# [INFO] Moving ../imgs/train/H/EMNIST_68739.png to ../imgs/validation/H/EMNIST_68739.png
# [INFO] Moving ../imgs/train/H/EMNIST_55785.png to ../imgs/validation/H/EMNIST_55785.png
# [INFO] Moving ../imgs/train/H/EMNIST_15918.png to ../imgs/validation/H/EMNIST_15918.png
# [INFO] Moving ../imgs/train/H/EMNIST_92861.png to ../imgs/validation/H/EMNIST_92861.png
# [INFO] Moving ../imgs/train/H/EMNIST_96747.png to ../imgs/validation/H/EMNIST_96747.png
# [INFO] Moving ../imgs/train/H/EMNIST_7639.png to ../imgs/validation/H/EMNIST_7639.png
# [INFO] Moving ../imgs/train/H/EMNIST_52745.png to ../imgs/validation/H/EMNIST_52745.png
# [INFO] Moving ../imgs/train/H/EMNIST_22736.png to ../imgs/validation/H/EMNIST_22736.png
# [INFO] Moving ../imgs/train/H/EMNIST_21616.png to ../imgs/validation/H/EMNIST_21616.png
# [INFO] Moving ../imgs/train/H/EMNIST_84894.png to ../imgs/validation/H/EMNIST_84894.png
# [INFO] Moving ../imgs/train/H/EMNIST_18248.png to ../imgs/validation/H/EMNIST_18248.png
# [INFO] Moving ../imgs/train/H/EMNIST_61742.png to ../imgs/validation/H/EMNIST_61742.png
# [INFO] Moving ../imgs/train/H/EMNIST_18262.png to ../imgs/validation/H/EMNIST_18262.png
# [INFO] Moving ../imgs/train/H/EMNIST_66896.png to ../imgs/validation/H/EMNIST_66896.png
# [INFO] Moving ../imgs/train/H/EMNIST_39256.png to ../imgs/validation/H/EMNIST_39256.png
# [INFO] Moving ../imgs/train/H/EMNIST_29481.png to ../imgs/validation/H/EMNIST_29481.png
# [INFO] Moving ../imgs/train/H/EMNIST_36432.png to ../imgs/validation/H/EMNIST_36432.png
# [INFO] Moving ../imgs/train/H/EMNIST_15004.png to ../imgs/validation/H/EMNIST_15004.png
# [INFO] Moving ../imgs/train/H/EMNIST_92950.png to ../imgs/validation/H/EMNIST_92950.png
# [INFO] Moving ../imgs/train/H/EMNIST_39983.png to ../imgs/validation/H/EMNIST_39983.png
# [INFO] Moving ../imgs/train/H/EMNIST_10121.png to ../imgs/validation/H/EMNIST_10121.png
# [INFO] Moving ../imgs/train/H/EMNIST_40040.png to ../imgs/validation/H/EMNIST_40040.png
# [INFO] Moving ../imgs/train/H/EMNIST_24194.png to ../imgs/validation/H/EMNIST_24194.png
# [INFO] Moving ../imgs/train/H/EMNIST_22579.png to ../imgs/validation/H/EMNIST_22579.png
# [INFO] Moving ../imgs/train/H/EMNIST_13944.png to ../imgs/validation/H/EMNIST_13944.png
# [INFO] Moving ../imgs/train/H/EMNIST_97008.png to ../imgs/validation/H/EMNIST_97008.png
# [INFO] Moving ../imgs/train/H/EMNIST_53404.png to ../imgs/validation/H/EMNIST_53404.png
# [INFO] Moving ../imgs/train/H/EMNIST_98767.png to ../imgs/validation/H/EMNIST_98767.png
# [INFO] Moving ../imgs/train/H/EMNIST_22476.png to ../imgs/validation/H/EMNIST_22476.png
# [INFO] Moving ../imgs/train/H/EMNIST_60705.png to ../imgs/validation/H/EMNIST_60705.png
# [INFO] Moving ../imgs/train/H/EMNIST_38723.png to ../imgs/validation/H/EMNIST_38723.png
# ...
# [INFO] Moving ../imgs/train/S/EMNIST_10179.png to ../imgs/validation/S/EMNIST_10179.png
# [INFO] Moving ../imgs/train/S/EMNIST_106146.png to ../imgs/validation/S/EMNIST_106146.png
# [INFO] Moving ../imgs/train/S/EMNIST_55024.png to ../imgs/validation/S/EMNIST_55024.png
# [INFO] Moving ../imgs/train/S/EMNIST_2538.png to ../imgs/validation/S/EMNIST_2538.png
# [INFO] Moving ../imgs/train/S/EMNIST_63573.png to ../imgs/validation/S/EMNIST_63573.png
# [INFO] Moving ../imgs/train/S/EMNIST_9919.png to ../imgs/validation/S/EMNIST_9919.png
# [INFO] Moving ../imgs/train/S/EMNIST_84944.png to ../imgs/validation/S/EMNIST_84944.png
# [INFO] Moving ../imgs/train/S/EMNIST_31383.png to ../imgs/validation/S/EMNIST_31383.png
# [INFO] Moving ../imgs/train/S/EMNIST_43332.png to ../imgs/validation/S/EMNIST_43332.png
# [INFO] Moving ../imgs/train/S/EMNIST_39696.png to ../imgs/validation/S/EMNIST_39696.png
# [INFO] Moving ../imgs/train/S/EMNIST_67328.png to ../imgs/validation/S/EMNIST_67328.png
# [INFO] Moving ../imgs/train/S/EMNIST_43416.png to ../imgs/validation/S/EMNIST_43416.png
# [INFO] Moving ../imgs/train/S/EMNIST_23234.png to ../imgs/validation/S/EMNIST_23234.png
# [INFO] Moving ../imgs/train/S/EMNIST_56161.png to ../imgs/validation/S/EMNIST_56161.png
# [INFO] Moving ../imgs/train/S/EMNIST_10775.png to ../imgs/validation/S/EMNIST_10775.png
# [INFO] Moving ../imgs/train/S/EMNIST_7586.png to ../imgs/validation/S/EMNIST_7586.png
# [INFO] Moving ../imgs/train/S/EMNIST_17447.png to ../imgs/validation/S/EMNIST_17447.png
# [INFO] Moving ../imgs/train/S/EMNIST_9471.png to ../imgs/validation/S/EMNIST_9471.png
# [INFO] Moving ../imgs/train/S/EMNIST_41076.png to ../imgs/validation/S/EMNIST_41076.png
# [INFO] Moving ../imgs/train/S/EMNIST_73254.png to ../imgs/validation/S/EMNIST_73254.png
# [INFO] Moving ../imgs/train/S/EMNIST_81785.png to ../imgs/validation/S/EMNIST_81785.png
# [INFO] Moving ../imgs/train/S/EMNIST_34850.png to ../imgs/validation/S/EMNIST_34850.png
# [INFO] Moving ../imgs/train/S/EMNIST_109711.png to ../imgs/validation/S/EMNIST_109711.png
# [INFO] Moving ../imgs/train/S/EMNIST_54561.png to ../imgs/validation/S/EMNIST_54561.png
# [INFO] Moving ../imgs/train/S/EMNIST_75596.png to ../imgs/validation/S/EMNIST_75596.png
# [INFO] Moving ../imgs/train/S/EMNIST_43368.png to ../imgs/validation/S/EMNIST_43368.png
# [INFO] Moving ../imgs/train/S/EMNIST_48368.png to ../imgs/validation/S/EMNIST_48368.png
# [INFO] Moving ../imgs/train/S/EMNIST_28955.png to ../imgs/validation/S/EMNIST_28955.png
# [INFO] Moving ../imgs/train/S/EMNIST_82343.png to ../imgs/validation/S/EMNIST_82343.png
# [INFO] Moving ../imgs/train/S/EMNIST_16606.png to ../imgs/validation/S/EMNIST_16606.png
# [INFO] Moving ../imgs/train/S/EMNIST_39339.png to ../imgs/validation/S/EMNIST_39339.png
# [INFO] Moving ../imgs/train/S/EMNIST_74068.png to ../imgs/validation/S/EMNIST_74068.png
# [INFO] Moving ../imgs/train/S/EMNIST_26760.png to ../imgs/validation/S/EMNIST_26760.png
# [INFO] Moving ../imgs/train/S/EMNIST_107865.png to ../imgs/validation/S/EMNIST_107865.png
# [INFO] Moving ../imgs/train/S/EMNIST_100804.png to ../imgs/validation/S/EMNIST_100804.png
# [INFO] Moving ../imgs/train/S/EMNIST_53954.png to ../imgs/validation/S/EMNIST_53954.png
# [INFO] Moving ../imgs/train/S/EMNIST_21181.png to ../imgs/validation/S/EMNIST_21181.png
# [INFO] Moving ../imgs/train/S/EMNIST_27599.png to ../imgs/validation/S/EMNIST_27599.png
# [INFO] Moving ../imgs/train/S/EMNIST_108955.png to ../imgs/validation/S/EMNIST_108955.png
# [INFO] Moving ../imgs/train/S/EMNIST_39137.png to ../imgs/validation/S/EMNIST_39137.png
# [INFO] Moving ../imgs/train/S/EMNIST_88087.png to ../imgs/validation/S/EMNIST_88087.png
# [INFO] Moving ../imgs/train/S/EMNIST_14375.png to ../imgs/validation/S/EMNIST_14375.png
# [INFO] Moving ../imgs/train/S/EMNIST_9396.png to ../imgs/validation/S/EMNIST_9396.png
# [INFO] Moving ../imgs/train/S/EMNIST_11786.png to ../imgs/validation/S/EMNIST_11786.png
# [INFO] Moving ../imgs/train/S/EMNIST_27542.png to ../imgs/validation/S/EMNIST_27542.png
# [INFO] Moving ../imgs/train/S/EMNIST_211.png to ../imgs/validation/S/EMNIST_211.png
# [INFO] Moving ../imgs/train/S/EMNIST_10461.png to ../imgs/validation/S/EMNIST_10461.png
# [INFO] Moving ../imgs/train/S/EMNIST_105383.png to ../imgs/validation/S/EMNIST_105383.png
# [INFO] Moving ../imgs/train/S/EMNIST_57399.png to ../imgs/validation/S/EMNIST_57399.png
# [INFO] Moving ../imgs/train/S/EMNIST_48010.png to ../imgs/validation/S/EMNIST_48010.png
# [INFO] Moving ../imgs/train/S/EMNIST_60030.png to ../imgs/validation/S/EMNIST_60030.png
# [INFO] Moving ../imgs/train/S/EMNIST_75176.png to ../imgs/validation/S/EMNIST_75176.png
# [INFO] Moving ../imgs/train/S/EMNIST_97384.png to ../imgs/validation/S/EMNIST_97384.png
# [INFO] Moving ../imgs/train/S/EMNIST_31582.png to ../imgs/validation/S/EMNIST_31582.png
# [INFO] Moving ../imgs/train/S/EMNIST_2897.png to ../imgs/validation/S/EMNIST_2897.png
# [INFO] Moving ../imgs/train/S/EMNIST_55714.png to ../imgs/validation/S/EMNIST_55714.png
# [INFO] Moving ../imgs/train/S/EMNIST_2306.png to ../imgs/validation/S/EMNIST_2306.png
# [INFO] Moving ../imgs/train/S/EMNIST_29163.png to ../imgs/validation/S/EMNIST_29163.png
# [INFO] Moving ../imgs/train/S/EMNIST_80620.png to ../imgs/validation/S/EMNIST_80620.png
# [INFO] Moving ../imgs/train/S/EMNIST_11105.png to ../imgs/validation/S/EMNIST_11105.png
# [INFO] Moving ../imgs/train/S/EMNIST_33792.png to ../imgs/validation/S/EMNIST_33792.png
# [INFO] Moving ../imgs/train/S/EMNIST_1173.png to ../imgs/validation/S/EMNIST_1173.png
# [INFO] Moving ../imgs/train/S/EMNIST_105599.png to ../imgs/validation/S/EMNIST_105599.png
# [INFO] Moving ../imgs/train/S/EMNIST_26926.png to ../imgs/validation/S/EMNIST_26926.png
# [INFO] Moving ../imgs/train/S/EMNIST_49838.png to ../imgs/validation/S/EMNIST_49838.png
# [INFO] Moving ../imgs/train/S/EMNIST_26273.png to ../imgs/validation/S/EMNIST_26273.png
# [INFO] Moving ../imgs/train/S/EMNIST_104805.png to ../imgs/validation/S/EMNIST_104805.png
# [INFO] Moving ../imgs/train/S/EMNIST_51650.png to ../imgs/validation/S/EMNIST_51650.png
# [INFO] Moving ../imgs/train/S/EMNIST_94924.png to ../imgs/validation/S/EMNIST_94924.png
# [INFO] Moving ../imgs/train/S/EMNIST_89601.png to ../imgs/validation/S/EMNIST_89601.png
# [INFO] Moving ../imgs/train/S/EMNIST_109006.png to ../imgs/validation/S/EMNIST_109006.png
# [INFO] Moving ../imgs/train/S/EMNIST_95628.png to ../imgs/validation/S/EMNIST_95628.png
# [INFO] Moving ../imgs/train/S/EMNIST_77134.png to ../imgs/validation/S/EMNIST_77134.png
# [INFO] Moving ../imgs/train/S/EMNIST_34057.png to ../imgs/validation/S/EMNIST_34057.png
# [INFO] Moving ../imgs/train/S/EMNIST_15514.png to ../imgs/validation/S/EMNIST_15514.png
# [INFO] Moving ../imgs/train/S/EMNIST_72620.png to ../imgs/validation/S/EMNIST_72620.png
# [INFO] Moving ../imgs/train/S/EMNIST_87630.png to ../imgs/validation/S/EMNIST_87630.png
# [INFO] Moving ../imgs/train/S/EMNIST_96846.png to ../imgs/validation/S/EMNIST_96846.png
# [INFO] Moving ../imgs/train/S/EMNIST_46286.png to ../imgs/validation/S/EMNIST_46286.png
# [INFO] Moving ../imgs/train/S/EMNIST_62409.png to ../imgs/validation/S/EMNIST_62409.png
# [INFO] Moving ../imgs/train/S/EMNIST_93347.png to ../imgs/validation/S/EMNIST_93347.png
# [INFO] Moving ../imgs/train/S/EMNIST_36129.png to ../imgs/validation/S/EMNIST_36129.png
# [INFO] Moving ../imgs/train/S/EMNIST_2458.png to ../imgs/validation/S/EMNIST_2458.png
# [INFO] Moving ../imgs/train/S/EMNIST_93159.png to ../imgs/validation/S/EMNIST_93159.png
# [INFO] Moving ../imgs/train/S/EMNIST_7867.png to ../imgs/validation/S/EMNIST_7867.png
# [INFO] Moving ../imgs/train/S/EMNIST_102097.png to ../imgs/validation/S/EMNIST_102097.png
# [INFO] Moving ../imgs/train/S/EMNIST_42015.png to ../imgs/validation/S/EMNIST_42015.png
# [INFO] Moving ../imgs/train/S/EMNIST_5730.png to ../imgs/validation/S/EMNIST_5730.png
# [INFO] Moving ../imgs/train/S/EMNIST_44088.png to ../imgs/validation/S/EMNIST_44088.png
# [INFO] Moving ../imgs/train/S/EMNIST_21037.png to ../imgs/validation/S/EMNIST_21037.png
# [INFO] Moving ../imgs/train/S/EMNIST_89338.png to ../imgs/validation/S/EMNIST_89338.png
# [INFO] Moving ../imgs/train/S/EMNIST_51914.png to ../imgs/validation/S/EMNIST_51914.png
# [INFO] Moving ../imgs/train/S/EMNIST_43289.png to ../imgs/validation/S/EMNIST_43289.png
# [INFO] Moving ../imgs/train/S/EMNIST_59983.png to ../imgs/validation/S/EMNIST_59983.png
# [INFO] Moving ../imgs/train/S/EMNIST_65023.png to ../imgs/validation/S/EMNIST_65023.png
# [INFO] Moving ../imgs/train/S/EMNIST_52295.png to ../imgs/validation/S/EMNIST_52295.png
# [INFO] Moving ../imgs/train/S/EMNIST_5533.png to ../imgs/validation/S/EMNIST_5533.png
# [INFO] Moving ../imgs/train/S/EMNIST_88453.png to ../imgs/validation/S/EMNIST_88453.png
# [INFO] Moving ../imgs/train/S/EMNIST_9197.png to ../imgs/validation/S/EMNIST_9197.png
# [INFO] Moving ../imgs/train/S/EMNIST_61566.png to ../imgs/validation/S/EMNIST_61566.png
# [INFO] Moving ../imgs/train/S/EMNIST_58662.png to ../imgs/validation/S/EMNIST_58662.png
# [INFO] Moving ../imgs/train/S/EMNIST_11567.png to ../imgs/validation/S/EMNIST_11567.png
# [INFO] Moving ../imgs/train/S/EMNIST_41525.png to ../imgs/validation/S/EMNIST_41525.png
# [INFO] Moving ../imgs/train/S/EMNIST_92462.png to ../imgs/validation/S/EMNIST_92462.png
# [INFO] Moving ../imgs/train/S/EMNIST_37452.png to ../imgs/validation/S/EMNIST_37452.png
# [INFO] Moving ../imgs/train/S/EMNIST_19057.png to ../imgs/validation/S/EMNIST_19057.png
# [INFO] Moving ../imgs/train/S/EMNIST_49156.png to ../imgs/validation/S/EMNIST_49156.png
# [INFO] Moving ../imgs/train/S/EMNIST_8057.png to ../imgs/validation/S/EMNIST_8057.png
# [INFO] Moving ../imgs/train/S/EMNIST_106768.png to ../imgs/validation/S/EMNIST_106768.png
# [INFO] Moving ../imgs/train/S/EMNIST_28776.png to ../imgs/validation/S/EMNIST_28776.png
# [INFO] Moving ../imgs/train/S/EMNIST_55223.png to ../imgs/validation/S/EMNIST_55223.png
# [INFO] Moving ../imgs/train/S/EMNIST_72796.png to ../imgs/validation/S/EMNIST_72796.png
# [INFO] Moving ../imgs/train/S/EMNIST_2430.png to ../imgs/validation/S/EMNIST_2430.png
# [INFO] Moving ../imgs/train/S/EMNIST_89130.png to ../imgs/validation/S/EMNIST_89130.png
# [INFO] Moving ../imgs/train/S/EMNIST_46725.png to ../imgs/validation/S/EMNIST_46725.png
# [INFO] Moving ../imgs/train/S/EMNIST_3193.png to ../imgs/validation/S/EMNIST_3193.png
# [INFO] Moving ../imgs/train/S/EMNIST_44001.png to ../imgs/validation/S/EMNIST_44001.png
# [INFO] Moving ../imgs/train/S/EMNIST_104876.png to ../imgs/validation/S/EMNIST_104876.png
# [INFO] Moving ../imgs/train/S/EMNIST_104321.png to ../imgs/validation/S/EMNIST_104321.png
# [INFO] Moving ../imgs/train/S/EMNIST_66779.png to ../imgs/validation/S/EMNIST_66779.png
# [INFO] Moving ../imgs/train/S/EMNIST_62347.png to ../imgs/validation/S/EMNIST_62347.png
# [INFO] Moving ../imgs/train/S/EMNIST_93341.png to ../imgs/validation/S/EMNIST_93341.png
# [INFO] Moving ../imgs/train/S/EMNIST_105223.png to ../imgs/validation/S/EMNIST_105223.png
# [INFO] Moving ../imgs/train/S/EMNIST_104431.png to ../imgs/validation/S/EMNIST_104431.png
# [INFO] Moving ../imgs/train/S/EMNIST_111660.png to ../imgs/validation/S/EMNIST_111660.png
# [INFO] Moving ../imgs/train/S/EMNIST_73812.png to ../imgs/validation/S/EMNIST_73812.png
# [INFO] Moving ../imgs/train/S/EMNIST_77477.png to ../imgs/validation/S/EMNIST_77477.png
# [INFO] Moving ../imgs/train/S/EMNIST_86615.png to ../imgs/validation/S/EMNIST_86615.png
# [INFO] Moving ../imgs/train/S/EMNIST_61952.png to ../imgs/validation/S/EMNIST_61952.png
# [INFO] Moving ../imgs/train/S/EMNIST_22410.png to ../imgs/validation/S/EMNIST_22410.png
# [INFO] Moving ../imgs/train/S/EMNIST_7543.png to ../imgs/validation/S/EMNIST_7543.png
# [INFO] Moving ../imgs/train/S/EMNIST_28753.png to ../imgs/validation/S/EMNIST_28753.png
# [INFO] Moving ../imgs/train/S/EMNIST_109988.png to ../imgs/validation/S/EMNIST_109988.png
# [INFO] Moving ../imgs/train/S/EMNIST_11819.png to ../imgs/validation/S/EMNIST_11819.png
# [INFO] Moving ../imgs/train/S/EMNIST_10037.png to ../imgs/validation/S/EMNIST_10037.png
# [INFO] Moving ../imgs/train/S/EMNIST_1073.png to ../imgs/validation/S/EMNIST_1073.png
# [INFO] Moving ../imgs/train/S/EMNIST_69284.png to ../imgs/validation/S/EMNIST_69284.png
# [INFO] Moving ../imgs/train/S/EMNIST_103194.png to ../imgs/validation/S/EMNIST_103194.png
# [INFO] Moving ../imgs/train/S/EMNIST_74178.png to ../imgs/validation/S/EMNIST_74178.png
# [INFO] Moving ../imgs/train/S/EMNIST_82189.png to ../imgs/validation/S/EMNIST_82189.png
# [INFO] Moving ../imgs/train/S/EMNIST_35867.png to ../imgs/validation/S/EMNIST_35867.png
# [INFO] Moving ../imgs/train/S/EMNIST_53692.png to ../imgs/validation/S/EMNIST_53692.png
# [INFO] Moving ../imgs/train/S/EMNIST_102349.png to ../imgs/validation/S/EMNIST_102349.png
# [INFO] Moving ../imgs/train/S/EMNIST_73546.png to ../imgs/validation/S/EMNIST_73546.png
# [INFO] Moving ../imgs/train/S/EMNIST_9567.png to ../imgs/validation/S/EMNIST_9567.png
# [INFO] Moving ../imgs/train/S/EMNIST_55703.png to ../imgs/validation/S/EMNIST_55703.png
# [INFO] Moving ../imgs/train/S/EMNIST_34170.png to ../imgs/validation/S/EMNIST_34170.png
# [INFO] Moving ../imgs/train/S/EMNIST_61562.png to ../imgs/validation/S/EMNIST_61562.png
# [INFO] Moving ../imgs/train/S/EMNIST_80186.png to ../imgs/validation/S/EMNIST_80186.png
# [INFO] Moving ../imgs/train/S/EMNIST_99372.png to ../imgs/validation/S/EMNIST_99372.png
# [INFO] Moving ../imgs/train/S/EMNIST_51524.png to ../imgs/validation/S/EMNIST_51524.png
# [INFO] Moving ../imgs/train/S/EMNIST_88162.png to ../imgs/validation/S/EMNIST_88162.png
# [INFO] Moving ../imgs/train/S/EMNIST_86599.png to ../imgs/validation/S/EMNIST_86599.png
# [INFO] Moving ../imgs/train/S/EMNIST_42645.png to ../imgs/validation/S/EMNIST_42645.png
# [INFO] Moving ../imgs/train/S/EMNIST_95476.png to ../imgs/validation/S/EMNIST_95476.png
# [INFO] Moving ../imgs/train/S/EMNIST_79457.png to ../imgs/validation/S/EMNIST_79457.png
# [INFO] Moving ../imgs/train/S/EMNIST_63251.png to ../imgs/validation/S/EMNIST_63251.png
# [INFO] Moving ../imgs/train/S/EMNIST_36246.png to ../imgs/validation/S/EMNIST_36246.png
# [INFO] Moving ../imgs/train/S/EMNIST_69394.png to ../imgs/validation/S/EMNIST_69394.png
# [INFO] Moving ../imgs/train/S/EMNIST_36164.png to ../imgs/validation/S/EMNIST_36164.png
# [INFO] Moving ../imgs/train/S/EMNIST_12656.png to ../imgs/validation/S/EMNIST_12656.png
# [INFO] Moving ../imgs/train/S/EMNIST_100451.png to ../imgs/validation/S/EMNIST_100451.png
# [INFO] Moving ../imgs/train/S/EMNIST_41509.png to ../imgs/validation/S/EMNIST_41509.png
# [INFO] Moving ../imgs/train/S/EMNIST_101780.png to ../imgs/validation/S/EMNIST_101780.png
# [INFO] Moving ../imgs/train/S/EMNIST_57193.png to ../imgs/validation/S/EMNIST_57193.png
# [INFO] Moving ../imgs/train/S/EMNIST_61156.png to ../imgs/validation/S/EMNIST_61156.png
# [INFO] Moving ../imgs/train/S/EMNIST_112360.png to ../imgs/validation/S/EMNIST_112360.png
# [INFO] Moving ../imgs/train/S/EMNIST_30802.png to ../imgs/validation/S/EMNIST_30802.png
# [INFO] Moving ../imgs/train/S/EMNIST_23786.png to ../imgs/validation/S/EMNIST_23786.png
# [INFO] Moving ../imgs/train/S/EMNIST_100459.png to ../imgs/validation/S/EMNIST_100459.png
# [INFO] Moving ../imgs/train/S/EMNIST_74336.png to ../imgs/validation/S/EMNIST_74336.png
# [INFO] Moving ../imgs/train/S/EMNIST_96046.png to ../imgs/validation/S/EMNIST_96046.png
# [INFO] Moving ../imgs/train/S/EMNIST_79395.png to ../imgs/validation/S/EMNIST_79395.png
# [INFO] Moving ../imgs/train/S/EMNIST_33479.png to ../imgs/validation/S/EMNIST_33479.png
# [INFO] Moving ../imgs/train/S/EMNIST_98951.png to ../imgs/validation/S/EMNIST_98951.png
# [INFO] Moving ../imgs/train/S/EMNIST_93917.png to ../imgs/validation/S/EMNIST_93917.png
# [INFO] Moving ../imgs/train/S/EMNIST_57930.png to ../imgs/validation/S/EMNIST_57930.png
# [INFO] Moving ../imgs/train/S/EMNIST_16059.png to ../imgs/validation/S/EMNIST_16059.png
# [INFO] Moving ../imgs/train/S/EMNIST_33424.png to ../imgs/validation/S/EMNIST_33424.png
# [INFO] Moving ../imgs/train/S/EMNIST_108637.png to ../imgs/validation/S/EMNIST_108637.png
# [INFO] Moving ../imgs/train/S/EMNIST_94292.png to ../imgs/validation/S/EMNIST_94292.png
